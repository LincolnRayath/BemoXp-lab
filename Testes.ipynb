# %% [markdown]
# # Tentando dar merge

# %%
import pandas as pd

arquivo = 'dados.xlsx'

realizado = pd.read_excel(arquivo, sheet_name='realizado')
orcado = pd.read_excel(arquivo, sheet_name='orcado')

planilha = [realizado, orcado]

merge = pd.concat(planilha)

#merge.to_excel('resultado.xlsx')
# Out:
# C:\Users\Linco\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # Remove the CWD from sys.path while we load stuff.

# %%
resultado = pd.read_excel('resultado.xlsx')

resultado.head(20)
# Out:
#              Mes_1   Mes_10    Mes_11    Mes_12      Mes_2  Mes_3  Mes_4  \
# NaN        janeiro  outubro  novembro  dezembro  fevereiro  março  abril
# Realizado      240      210       232       213        280    200    310
# 0              NaN      NaN       NaN       NaN        NaN    NaN    NaN
# 1              NaN      NaN       NaN       NaN        NaN    NaN    NaN
# 2              NaN      NaN       NaN       NaN        NaN    NaN    NaN
# 3              NaN      NaN       NaN       NaN        NaN    NaN    NaN
# 4              NaN      NaN       NaN       NaN        NaN    NaN    NaN
# 5              NaN      NaN       NaN       NaN        NaN    NaN    NaN
# 6              NaN      NaN       NaN       NaN        NaN    NaN    NaN
# 7              NaN      NaN       NaN       NaN        NaN    NaN    NaN
# 8              NaN      NaN       NaN       NaN        NaN    NaN    NaN
# 9              NaN      NaN       NaN       NaN        NaN    NaN    NaN
# ...

# %%
resultado.loc['Realizado']
# Out:
# Mes_1        240
# Mes_10       210
# Mes_11       232
# Mes_12       213
# Mes_2        280
# Mes_3        200
# Mes_4        310
# Mes_5        230
# Mes_6        213
# Mes_7        239
# Mes_8        210
# Mes_9        210
# mês          NaN
# orcado       NaN
# realizado    NaN
# Name: Realizado, dtype: object
